# %% [markdown]
# # TD 1: Fairness notion examples
#
# In this first TD we are going to manipulate some data and see the behaviour of the different fairness metrics

# %% [markdown]
# Environnement python3.10
#
# `python -m venv env`
#
# `source env/bin/activate`
#
# `python -m pip install -r requirements.txt`

# %% [markdown]
# ## Dataset: Diabetes 130-Hospitals
#
# https://fairlearn.org/main/api_reference/generated/fairlearn.datasets.fetch_diabetes_hospital.html

# %%
import fairlearn
from fairlearn.datasets import fetch_diabetes_hospital
dataset = fetch_diabetes_hospital()
# Out:
# /home/T0187710/secured/fairness_cours/env/lib/python3.10/site-packages/sklearn/datasets/_openml.py:1022: FutureWarning: The default value of `parser` will change from `'liac-arff'` to `'auto'` in 1.4. You can set `parser='auto'` to silence this warning. Therefore, an `ImportError` will be raised from 1.4 if the dataset is dense and pandas is not installed. Note that the pandas parser may return different data types. See the Notes Section in fetch_openml's API doc for details.
#   warn(

# %%
dataset.data
# Out:
#                    race  gender                  age discharge_disposition_id  \
# 0             Caucasian  Female  30 years or younger                    Other
# 1             Caucasian  Female  30 years or younger       Discharged to Home
# 2       AfricanAmerican  Female  30 years or younger       Discharged to Home
# 3             Caucasian    Male          30-60 years       Discharged to Home
# 4             Caucasian    Male          30-60 years       Discharged to Home
# ...                 ...     ...                  ...                      ...
# 101761  AfricanAmerican    Male        Over 60 years                    Other
# 101762  AfricanAmerican  Female        Over 60 years                    Other
# 101763        Caucasian    Male        Over 60 years       Discharged to Home
# 101764        Caucasian  Female        Over 60 years                    Other
# 101765        Caucasian    Male        Over 60 years       Discharged to Home
#
#        admission_source_id  time_in_hospital medical_specialty  \
# 0                 Referral                 1             Other
# 1                Emergency                 3           Missing
# 2                Emergency                 2           Missing
# 3                Emergency                 2           Missing
# 4                Emergency                 1           Missing
# ...                    ...               ...               ...
# 101761           Emergency                 3           Missing
# 101762               Other                 5           Missing
# 101763           Emergency                 1           Missing
# 101764           Emergency                10             Other
# 101765           Emergency                 6           Missing
#
#         num_lab_procedures  num_procedures  num_medications  ... insulin  \
# 0                       41               0                1  ...      No
# 1                       59               0               18  ...      Up
# 2                       11               5               13  ...      No
# 3                       44               1               16  ...      Up
# 4                       51               0                8  ...  Steady
# ...                    ...             ...              ...  ...     ...
# 101761                  51               0               16  ...    Down
# 101762                  33               3               18  ...  Steady
# 101763                  53               0                9  ...    Down
# 101764                  45               2               21  ...      Up
# 101765                  13               3                3  ...      No
#
#         change diabetesMed medicare medicaid had_emergency had_inpatient_days  \
# 0           No          No    False    False         False              False
# 1           Ch         Yes    False    False         False              False
# 2           No         Yes    False    False         False               True
# 3           Ch         Yes    False    False         False              False
# 4           Ch         Yes    False    False         False              False
# ...        ...         ...      ...      ...           ...                ...
# 101761      Ch         Yes     True    False         False              False
# 101762      No         Yes     True    False         False               True
# 101763      Ch         Yes     True    False         False              False
# 101764      Ch         Yes     True    False         False               True
# 101765      No          No    False    False         False              False
#
#        had_outpatient_days readmitted readmit_binary
# 0                    False         NO              0
# 1                    False        >30              1
# 2                     True         NO              0
# 3                    False         NO              0
# 4                    False         NO              0
# ...                    ...        ...            ...
# 101761               False        >30              1
# 101762               False         NO              0
# 101763                True         NO              0
# 101764               False         NO              0
# 101765               False         NO              0
#
# [101766 rows x 24 columns]
